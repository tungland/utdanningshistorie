# %%
import dhlab as dh

# %%
lærebøker = dh.Corpus(doctype="digibok", subject="lærebøker", limit=10000000)

# %%
lærebøker.frame.groupby("year").dhlabid.count().sort_index().median()
# Out:
# 9.0

# %%
lærebøker.frame.groupby("year").dhlabid.count().sort_index().mode()
# Out:
# 0    2
# Name: dhlabid, dtype: int64

# %%
lærebøker.frame.groupby("year").dhlabid.count().sort_index()
# Out:
# year
# 1777     1
# 1782     1
# 1794     1
# 1809     2
# 1811     2
#         ..
# 2017    80
# 2018    20
# 2019    30
# 2020     3
# 2021     4
# Name: dhlabid, Length: 189, dtype: int64

# %%
lærebøker.frame.groupby("year").dhlabid.count().sort_index().plot()
# Out:
# <Axes: xlabel='year'>
