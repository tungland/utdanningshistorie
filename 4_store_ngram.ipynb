# %%
import dhlab as dh

# %%
dh.Ngram(["Henrik Ibsen", "Bjørnstjerne Bjørnson", "Alexander Kielland", "Jonas Lie"], from_year=1850, to_year=2015, doctype="digavis").plot(smooth=10)

# %%
dh.Ngram(["Henrik Ibsen", "Bjørnstjerne Bjørnson", "Alexander Kielland", "Jonas Lie"], from_year=1850, to_year=2015).plot(smooth=10)

# %%
import numpy as np
import matplotlib.pyplot as plt

df = dh.Ngram(["Henrik Ibsen", "Bjørnstjerne Bjørnson", "Alexander Kielland", "Jonas Lie"], from_year=1850, to_year=2015).frame
